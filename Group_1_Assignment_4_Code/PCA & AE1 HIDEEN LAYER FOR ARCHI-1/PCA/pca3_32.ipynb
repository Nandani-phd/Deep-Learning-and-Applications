# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os,sys
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Input,Flatten,Reshape
from tensorflow.keras.models import Model
from keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import pickle as p
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix 

initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=100)


#print('Initializer: ',initializer)

def Upload_Dataset(Dataset_Path):
    
    Path_train_Dataset = Dataset_Path+"/train"
    Path_test_Dataset = Dataset_Path+"/test"
    Path_val_Dataset = Dataset_Path+"/val"
    
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = [], [], []
    Output_train, Output_test, Output_val = [], [], []

    for j in os.listdir(Path_train_Dataset):

        if j != ".DS_Store":
            for k in os.listdir(Path_train_Dataset+"/"+j):
                Input_train_Dataset.append(cv2.imread(Path_train_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j == '6'):
                    Output_train.append(int(2))
                elif(j == '7'):
                    Output_train.append(int(3))
                elif(j == '9'):
                    Output_train.append(int(4))
                else:
                    Output_train.append(int(j))

            for k in os.listdir(Path_test_Dataset+"/"+j):
                Input_test_Dataset.append(cv2.imread(Path_test_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_test.append(int(2))
                elif(j=='7'):
                    Output_test.append(int(3))
                elif(j=='9'):
                    Output_test.append(int(4))
                else:
                    Output_test.append(int(j))

            for k in os.listdir(Path_val_Dataset+"/"+j):
                Input_val_Dataset.append(cv2.imread(Path_val_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_val.append(int(2))
                elif(j=='7'):
                    Output_val.append(int(3))
                elif(j=='9'):
                    Output_val.append(int(4))
                else:
                    Output_val.append(int(j))
        
    #print(Output_train)            
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = np.array(Input_train_Dataset), np.array(Input_test_Dataset), np.array(Input_val_Dataset)
    #Output_train, Output_test, Output_val = np.array(list(map(int, Output_train))), np.array(list(map(int, Output_test))), np.array(list(map(int, Output_val)))
    Output_train, Output_test, Output_val = np.array(Output_train), np.array(Output_test), np.array(Output_val)
    #print(Output_train) 
    return Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val



#providing path of  MNIST dataset
Dataset_Path = "/content/drive/MyDrive/Group_1"


#calling Upload_Dataset function
Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val= Upload_Dataset(Dataset_Path)

Input_train_Dataset=Input_train_Dataset/255
Input_test_Dataset=Input_test_Dataset/255
Input_val_Dataset=Input_val_Dataset/255

#bottleneck dimension
pcaDim=32

xTrain=np.reshape(Input_train_Dataset,(Input_train_Dataset.shape[0],784))
xVal=np.reshape(Input_val_Dataset,(Input_val_Dataset.shape[0],784))
xTest=np.reshape(Input_test_Dataset,(Input_test_Dataset.shape[0],784))

pca=PCA(pcaDim)#based on arch
pcaFit=pca.fit(xTrain)

pcaTrain=pca.transform(xTrain)
trainReconstruct=pca.inverse_transform(pcaTrain).reshape(Input_train_Dataset.shape[0],28,28)

n=5
plt.figure(figsize=(20,10))
for i in range(n):
    #displaying original image
    #clss=n
    idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(2,n,i+1)
    plt.imshow(Input_train_Dataset[idx].reshape(28,28),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    #displaying reconstructed image
    ax=plt.subplot(2,n,i+1+n)
    plt.imshow(trainReconstruct[idx].reshape(28,28),cmap='gray')
    #plt.imshow(trainEncode[i].reshape(8,8),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()


pcaVal=pca.transform(xVal)
valReconstruct=pca.inverse_transform(pcaVal).reshape(Input_val_Dataset.shape[0],28,28)

n=5
plt.figure(figsize=(20,10))
for i in range(n):
    #displaying original image
    #clss=n
    idx=np.where(Output_val==i)[0][0]
    ax=plt.subplot(2,n,i+1)
    plt.imshow(Input_val_Dataset[idx].reshape(28,28),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    #displaying reconstructed image
    ax=plt.subplot(2,n,i+1+n)
    plt.imshow(valReconstruct[idx].reshape(28,28),cmap='gray')
    #plt.imshow(trainEncode[i].reshape(8,8),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()


pcaTest=pca.transform(xTest)
testReconstruct=pca.inverse_transform(pcaTest).reshape(Input_test_Dataset.shape[0],28,28)

n=5
plt.figure(figsize=(20,10))
for i in range(n):
    #displaying original image
    #clss=n
    idx=np.where(Output_test==i)[0][0]
    ax=plt.subplot(2,n,i+1)
    plt.imshow(Input_test_Dataset[idx].reshape(28,28),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    #displaying reconstructed image
    ax=plt.subplot(2,n,i+1+n)
    plt.imshow(testReconstruct[idx].reshape(28,28),cmap='gray')
    #plt.imshow(trainEncode[i].reshape(8,8),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

print(trainReconstruct)

model = keras.Sequential([
        #layers.Flatten(input_shape=(28, 28), name='InputLayer'),
        Dense(1024, activation="sigmoid", name="Hlayer1",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(512, activation="sigmoid", name="Hlayer2",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(128, activation="sigmoid", name="Hlayer3",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(5, activation="softmax", name="output"),
        ])

#model.summary()

adam =Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8,name='Adam')


model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=10,verbose=1)

model_fit = model.fit(x = pcaTrain, y = Output_train, batch_size = 32, epochs = 10000, verbose = "auto", callbacks=[es], validation_data=(pcaVal,  Output_val), validation_batch_size=1)
model.save('/content/drive/MyDrive/DLA4/PCA/pca3_32.h5')
f=open('/content/drive/MyDrive/DLA4/PCA/Histpca3_32.pckl','wb')
p.dump(model_fit.history,f)
f.close()


print('\nEvaluation of model on train data:')
trainAcc=model.evaluate(x=pcaTrain,y=Output_train,batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(trainAcc)

print('\nEvaluation of model on validation data:')
valAcc=model.evaluate(x=pcaVal, y=Output_val, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(valAcc)

print('\nEvaluation of model on test data:')
testAcc=model.evaluate(x=pcaTest, y=Output_test, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(testAcc)

print('\nPredictions for test data:')
testProb=model.predict(pcaTest, batch_size=1, verbose="auto", callbacks=None)
pred=np.argmax(testProb,axis=1)
print(pred)
#confusionMatrix=confusion_matrix(Output_test, pred)
confusionMatrix=confusion_matrix(Output_test,pred)
#confusionMatrix=tf.math.confusion_matrix(Output_test, pred5)
print(confusionMatrix)
# Out:
# [[[-3.01314133e-04 -7.71647265e-04 -7.40628782e-04 ...  3.00167214e-05
#     2.07736367e-04  2.22439813e-04]
#   [-9.66146969e-04 -2.24658549e-04 -4.13141658e-04 ...  1.91397072e-04
#     8.76379986e-05  1.11493702e-04]
#   [-2.40244246e-04 -3.04269096e-04 -4.84735919e-04 ...  2.36054236e-04
#     1.57209462e-04  1.35214481e-04]
#   ...
#   [-7.93381193e-04 -7.81416590e-04 -1.21703533e-03 ... -7.50608596e-05
#    -2.19888134e-05 -3.17108362e-05]
#   [-9.19686884e-04 -8.53288032e-04 -6.51014466e-04 ... -5.57966501e-05
#    -6.21507280e-05  5.73959663e-06]
#   [-5.68232668e-04 -7.54815343e-04 -9.88311808e-04 ... -6.52405847e-05
#    -5.91828873e-06 -2.44312474e-05]]
#
#  [[-4.93246945e-04 -1.03785362e-03 -8.70566403e-04 ... -3.63829681e-04
#    -3.02028932e-04 -2.77727943e-04]
#   [-1.08299986e-03 -7.69498519e-04 -8.77996387e-04 ... -3.85376727e-04
#    -2.88199389e-04 -4.13865879e-04]
#   [-1.37248876e-03 -4.33132434e-04 -2.04119371e-04 ... -5.93211084e-04
#    -2.37413933e-04 -4.19238244e-04]
#   ...
#   [-8.10573964e-04 -1.07084942e-03 -9.98001434e-04 ... -8.86341951e-05
#    -1.87765717e-05  8.21093951e-06]
#   [-7.93874093e-04 -9.25500222e-04 -6.37199716e-04 ... -4.82127918e-05
#    -4.97889490e-05  4.72641873e-06]
#   [-5.43065262e-04 -6.28696473e-04 -9.14810808e-04 ... -3.20135386e-05
#     1.39100715e-05 -2.91661588e-05]]
#
#  [[-1.08445622e-03 -2.11120366e-03 -1.56506062e-03 ... -1.95527473e-04
#    -8.41237925e-05 -1.89403239e-04]
#   [-1.76215220e-03 -1.30093734e-03 -1.68383517e-03 ... -1.71051157e-04
#    -2.08056978e-04 -1.89237070e-04]
#   [-2.26065268e-03 -9.86708405e-04 -1.10294991e-03 ... -5.12581824e-04
#    -9.70551494e-05 -1.21739332e-04]
#   ...
#   [ 5.17617304e-05  4.75641521e-04  3.75833603e-04 ...  8.79323568e-05
#    -5.85987583e-06  6.45644079e-05]
#   [ 1.36467229e-04  1.85464081e-04  1.71196443e-04 ... -2.00999045e-05
#     1.84734160e-05  5.30975710e-05]
#   [ 2.75143770e-04  1.54540301e-04  2.69846584e-04 ...  3.13581825e-05
#     7.86678487e-05  1.54780157e-05]]
#
#  ...
#
#  [[ 1.49099749e-03  1.65013339e-03  1.17971494e-03 ...  3.72774978e-04
#     6.12834327e-04  3.90778632e-04]
#   [ 1.25939952e-03  1.52658417e-03  1.70163811e-03 ...  3.54403796e-04
#     4.55795184e-04  5.00123178e-04]
#   [ 1.77772621e-03  1.17726400e-03  1.07950954e-03 ...  1.22458407e-03
#     2.59315777e-04  4.60231318e-04]
#   ...
#   [-1.84874016e-03 -1.29822631e-03 -2.14169138e-03 ...  4.87172351e-05
#    -1.26743390e-05 -7.38124686e-06]
#   [-1.78587222e-03 -1.24221382e-03 -1.51557224e-03 ... -3.37842244e-05
#    -3.06104493e-05  3.80392688e-06]
#   [-1.09725594e-03 -1.22899430e-03 -1.89136770e-03 ... -2.41649801e-05
#     4.62130639e-06  2.68648413e-05]]
#
#  [[ 6.00768488e-04  4.27665430e-04  2.00755450e-04 ...  2.04062576e-05
#     2.08594303e-04  1.67189283e-04]
#   [ 2.56539796e-04  7.97398178e-04  7.52233237e-04 ...  1.49024484e-04
#     1.02088137e-04  1.44840076e-04]
#   [ 6.52316907e-04  3.82379715e-04  5.71363362e-05 ...  2.27156005e-04
#     9.78288163e-05  1.29465142e-04]
#   ...
#   [ 6.91001144e-04  4.99463472e-04  1.18409311e-03 ...  8.71788346e-05
#     1.31991419e-05  5.16108958e-05]
#   [ 6.20461378e-04  7.07384707e-04  6.44274316e-04 ...  4.03000822e-05
#     4.34266192e-05  2.63591128e-05]
#   [ 5.60371176e-04  6.94564531e-04  5.82348701e-04 ...  5.35466198e-05
#     2.62539134e-05  1.29117796e-05]]
#
#  [[ 5.70133395e-03  5.83214935e-03  5.39206729e-03 ... -5.22029711e-05
#    -1.33013513e-04 -1.69801156e-04]
#   [ 6.21969856e-03  6.01846133e-03  6.54746471e-03 ... -1.75245545e-04
#    -1.77760487e-04 -1.62141998e-04]
#   [ 6.92252933e-03  4.45088817e-03  3.54111090e-03 ... -2.01650730e-04
#    -7.16989917e-05 -1.73452191e-04]
#   ...
#   [ 1.69524931e-03  1.36616593e-03  1.37141081e-03 ...  1.44515230e-06
#     2.53245036e-05 -3.61288026e-05]
#   [ 1.59451458e-03  1.66690245e-03  1.42638845e-03 ...  5.67918318e-05
#    -2.56906938e-05 -2.46676567e-05]
#   [ 9.87396449e-04  1.23840355e-03  1.52393920e-03 ... -5.41342282e-06
#    -2.28736638e-05  4.28188840e-06]]]
# Epoch 1/10000
# 356/356 [==============================] - 17s 46ms/step - loss: 0.4178 - accuracy: 0.8634 - val_loss: 0.1259 - val_accuracy: 0.9618
# Epoch 2/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 0.1313 - accuracy: 0.9584 - val_loss: 0.1205 - val_accuracy: 0.9607
# Epoch 3/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.1198 - accuracy: 0.9612 - val_loss: 0.1416 - val_accuracy: 0.9542
# Epoch 4/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.1118 - accuracy: 0.9643 - val_loss: 0.0994 - val_accuracy: 0.9692
# Epoch 5/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.1000 - accuracy: 0.9695 - val_loss: 0.0951 - val_accuracy: 0.9697
# Epoch 6/10000
# 356/356 [==============================] - 17s 47ms/step - loss: 0.0966 - accuracy: 0.9695 - val_loss: 0.0938 - val_accuracy: 0.9686
# Epoch 7/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 0.0840 - accuracy: 0.9738 - val_loss: 0.0938 - val_accuracy: 0.9686
# Epoch 8/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 0.0813 - accuracy: 0.9740 - val_loss: 0.0884 - val_accuracy: 0.9726
# Epoch 9/10000
# 356/356 [==============================] - 16s 46ms/step - loss: 0.0755 - accuracy: 0.9762 - val_loss: 0.0871 - val_accuracy: 0.9726
# Epoch 10/10000
# 356/356 [==============================] - 17s 47ms/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 0.0813 - val_accuracy: 0.9760
# Epoch 11/10000
# 356/356 [==============================] - 16s 45ms/step - loss: 0.0650 - accuracy: 0.9796 - val_loss: 0.0702 - val_accuracy: 0.9755
# Epoch 12/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 0.0631 - accuracy: 0.9787 - val_loss: 0.0765 - val_accuracy: 0.9752
# Epoch 13/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0602 - accuracy: 0.9809 - val_loss: 0.0877 - val_accuracy: 0.9713
# Epoch 14/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0569 - accuracy: 0.9815 - val_loss: 0.0694 - val_accuracy: 0.9779
# Epoch 15/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0566 - accuracy: 0.9812 - val_loss: 0.0660 - val_accuracy: 0.9805
# Epoch 16/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0499 - accuracy: 0.9845 - val_loss: 0.0704 - val_accuracy: 0.9794
# Epoch 17/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0495 - accuracy: 0.9840 - val_loss: 0.0668 - val_accuracy: 0.9802
# Epoch 18/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0494 - accuracy: 0.9835 - val_loss: 0.0735 - val_accuracy: 0.9747
# Epoch 19/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0427 - accuracy: 0.9869 - val_loss: 0.0699 - val_accuracy: 0.9792
# Epoch 20/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0440 - accuracy: 0.9860 - val_loss: 0.0734 - val_accuracy: 0.9763
# Epoch 21/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 0.0712 - val_accuracy: 0.9781
# Epoch 22/10000
# 356/356 [==============================] - 10s 29ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.0703 - val_accuracy: 0.9784
# Epoch 23/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 0.0346 - accuracy: 0.9887 - val_loss: 0.0687 - val_accuracy: 0.9802
# Epoch 24/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 0.0363 - accuracy: 0.9881 - val_loss: 0.0682 - val_accuracy: 0.9805
# Epoch 25/10000
# 356/356 [==============================] - 12s 32ms/step - loss: 0.0304 - accuracy: 0.9903 - val_loss: 0.0659 - val_accuracy: 0.9810
# Epoch 26/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0709 - val_accuracy: 0.9810
# Epoch 27/10000
# 356/356 [==============================] - 10s 29ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 0.0736 - val_accuracy: 0.9792
# Epoch 28/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0279 - accuracy: 0.9910 - val_loss: 0.0774 - val_accuracy: 0.9797
# Epoch 29/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 0.0660 - val_accuracy: 0.9821
# Epoch 30/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0695 - val_accuracy: 0.9805
# Epoch 31/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.0823 - val_accuracy: 0.9773
# Epoch 32/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0707 - val_accuracy: 0.9810
# Epoch 33/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.0825 - val_accuracy: 0.9789
# Epoch 34/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0767 - val_accuracy: 0.9810
# Epoch 35/10000
# 356/356 [==============================] - 10s 30ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0807 - val_accuracy: 0.9797
# Epoch 36/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0831 - val_accuracy: 0.9789
# Epoch 37/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0745 - val_accuracy: 0.9808
# Epoch 38/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.0743 - val_accuracy: 0.9829
# Epoch 39/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0749 - val_accuracy: 0.9826
# Epoch 40/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0805 - val_accuracy: 0.9810
# Epoch 41/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0791 - val_accuracy: 0.9797
# Epoch 42/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0758 - val_accuracy: 0.9823
# Epoch 43/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0742 - val_accuracy: 0.9829
# Epoch 44/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0793 - val_accuracy: 0.9808
# Epoch 45/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0754 - val_accuracy: 0.9831
# Epoch 46/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0701 - val_accuracy: 0.9847
# Epoch 47/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0843 - val_accuracy: 0.9800
# Epoch 48/10000
# 356/356 [==============================] - 12s 32ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0797 - val_accuracy: 0.9834
# Epoch 49/10000
# 356/356 [==============================] - 10s 28ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0815 - val_accuracy: 0.9837
# Epoch 50/10000
# 356/356 [==============================] - 16s 46ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0877 - val_accuracy: 0.9818
# Epoch 51/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.0782 - val_accuracy: 0.9834
# Epoch 52/10000
# 356/356 [==============================] - 11s 31ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0839 - val_accuracy: 0.9826
# Epoch 53/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0788 - val_accuracy: 0.9842
# Epoch 54/10000
# 356/356 [==============================] - 10s 28ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0846 - val_accuracy: 0.9829
# Epoch 55/10000
# 356/356 [==============================] - 16s 46ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0865 - val_accuracy: 0.9826
# Epoch 56/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0885 - val_accuracy: 0.9834
# Epoch 57/10000
# 356/356 [==============================] - 10s 29ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0868 - val_accuracy: 0.9821
# Epoch 58/10000
# 356/356 [==============================] - 16s 45ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0872 - val_accuracy: 0.9837
# Epoch 59/10000
# 356/356 [==============================] - 10s 28ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0784 - val_accuracy: 0.9839
# Epoch 60/10000
# 356/356 [==============================] - 17s 47ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0894 - val_accuracy: 0.9837
# Epoch 61/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0860 - val_accuracy: 0.9839
# Epoch 62/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0917 - val_accuracy: 0.9831
# Epoch 63/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0982 - val_accuracy: 0.9834
# Epoch 64/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 9.1227e-04 - accuracy: 0.9998 - val_loss: 0.0914 - val_accuracy: 0.9845
# Epoch 65/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0883 - val_accuracy: 0.9834
# Epoch 66/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.1051 - val_accuracy: 0.9800
# Epoch 67/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0944 - val_accuracy: 0.9834
# Epoch 68/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0956 - val_accuracy: 0.9829
# Epoch 69/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0883 - val_accuracy: 0.9842
# Epoch 70/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0876 - val_accuracy: 0.9829
# Epoch 71/10000
# 356/356 [==============================] - 11s 32ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0992 - val_accuracy: 0.9842
# Epoch 72/10000
# 356/356 [==============================] - 11s 31ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0946 - val_accuracy: 0.9831
# Epoch 73/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 7.4070e-04 - accuracy: 0.9997 - val_loss: 0.0976 - val_accuracy: 0.9837
# Epoch 74/10000
# 356/356 [==============================] - 11s 31ms/step - loss: 5.9497e-04 - accuracy: 0.9998 - val_loss: 0.0967 - val_accuracy: 0.9829
# Epoch 75/10000
# 356/356 [==============================] - 16s 44ms/step - loss: 4.9749e-04 - accuracy: 0.9999 - val_loss: 0.0994 - val_accuracy: 0.9837
# Epoch 76/10000
# 356/356 [==============================] - 11s 30ms/step - loss: 3.5045e-04 - accuracy: 0.9999 - val_loss: 0.1018 - val_accuracy: 0.9834
# Epoch 77/10000
# 356/356 [==============================] - 16s 45ms/step - loss: 3.2440e-04 - accuracy: 0.9999 - val_loss: 0.1051 - val_accuracy: 0.9837
# Epoch 78/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 0.0812 - val_accuracy: 0.9834
# Epoch 79/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0918 - val_accuracy: 0.9842
# Epoch 80/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0932 - val_accuracy: 0.9842
# Epoch 81/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 4.9102e-04 - accuracy: 0.9999 - val_loss: 0.0928 - val_accuracy: 0.9855
# Epoch 82/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 4.7773e-04 - accuracy: 0.9999 - val_loss: 0.0949 - val_accuracy: 0.9850
# Epoch 83/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 2.1942e-04 - accuracy: 0.9999 - val_loss: 0.0962 - val_accuracy: 0.9850
# Epoch 84/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 2.0906e-04 - accuracy: 0.9999 - val_loss: 0.0964 - val_accuracy: 0.9858
# Epoch 85/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 1.3185e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9852
# Epoch 86/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 1.0304e-04 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9858
# Epoch 87/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 6.1893e-05 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9858
# Epoch 88/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 4.0604e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9858
# Epoch 89/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 3.3947e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9858
# Epoch 90/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 2.8418e-05 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9855
# Epoch 91/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 2.4083e-05 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9858
# Epoch 92/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 2.0083e-05 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9858
# Epoch 93/10000
# 356/356 [==============================] - 15s 42ms/step - loss: 1.7255e-05 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9863
# Epoch 94/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 1.4598e-05 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9855
# Epoch 95/10000
# 356/356 [==============================] - 15s 43ms/step - loss: 1.4024e-05 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9855
# Epoch 96/10000
# 356/356 [==============================] - 12s 33ms/step - loss: 1.1995e-05 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9858
# Epoch 96: early stopping
#
# Evaluation of model on train data:
# 11385/11385 [==============================] - 24s 2ms/step - loss: 1.8313e-05 - accuracy: 1.0000
# ['loss', 'accuracy']
# [1.8312804968445562e-05, 1.0]
#
# Evaluation of model on validation data:
# 3795/3795 [==============================] - 8s 2ms/step - loss: 0.1129 - accuracy: 0.9858
# ['loss', 'accuracy']
# [0.11292378604412079, 0.9857707619667053]
#
# Evaluation of model on test data:
# 3795/3795 [==============================] - 8s 2ms/step - loss: 0.0915 - accuracy: 0.9837
# ['loss', 'accuracy']
# [0.09150192886590958, 0.9836627244949341]
#
# Predictions for test data:
# 3795/3795 [==============================] - 9s 2ms/step
# [0 0 0 ... 3 3 3]
# [[753   1   2   1   2]
#  [  1 751   3   4   0]
#  [  7   1 750   0   1]
#  [  1   3   3 741  11]
#  [  3   2   0  16 738]]
