# %% [markdown]
# #512,256,128

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os,sys
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Input,Flatten,Reshape
from tensorflow.keras.models import Model
from keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import pickle as p
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix 

initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=100)
#print('Initializer: ',initializer)

def Upload_Dataset(Dataset_Path):
    
    Path_train_Dataset = Dataset_Path+"/train"
    Path_test_Dataset = Dataset_Path+"/test"
    Path_val_Dataset = Dataset_Path+"/val"
    
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = [], [], []
    Output_train, Output_test, Output_val = [], [], []

    for j in os.listdir(Path_train_Dataset):

        if j != ".DS_Store":
            for k in os.listdir(Path_train_Dataset+"/"+j):
                Input_train_Dataset.append(cv2.imread(Path_train_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j == '6'):
                    Output_train.append(int(2))
                elif(j == '7'):
                    Output_train.append(int(3))
                elif(j == '9'):
                    Output_train.append(int(4))
                else:
                    Output_train.append(int(j))

            for k in os.listdir(Path_test_Dataset+"/"+j):
                Input_test_Dataset.append(cv2.imread(Path_test_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_test.append(int(2))
                elif(j=='7'):
                    Output_test.append(int(3))
                elif(j=='9'):
                    Output_test.append(int(4))
                else:
                    Output_test.append(int(j))

            for k in os.listdir(Path_val_Dataset+"/"+j):
                Input_val_Dataset.append(cv2.imread(Path_val_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_val.append(int(2))
                elif(j=='7'):
                    Output_val.append(int(3))
                elif(j=='9'):
                    Output_val.append(int(4))
                else:
                    Output_val.append(int(j))
        
    #print(Output_train)            
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = np.array(Input_train_Dataset), np.array(Input_test_Dataset), np.array(Input_val_Dataset)
    #Output_train, Output_test, Output_val = np.array(list(map(int, Output_train))), np.array(list(map(int, Output_test))), np.array(list(map(int, Output_val)))
    Output_train, Output_test, Output_val = np.array(Output_train), np.array(Output_test), np.array(Output_val)
    #print(Output_train) 
    return Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val



#providing path of  MNIST dataset
Dataset_Path = "/content/drive/MyDrive/Group_1"


#calling Upload_Dataset function
Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val= Upload_Dataset(Dataset_Path)
#print(Input_train_Dataset.shape,'\n')

#
Input_train_Dataset=Input_train_Dataset/255
Input_test_Dataset=Input_test_Dataset/255
Input_val_Dataset=Input_val_Dataset/255
'''bottleneck dimension'''
encodingDim=32
print(Input_train_Dataset.shape)

xInp=Input(shape=(28,28),name="img")
inp=Flatten(input_shape=(28, 28), name='InputLayer')(xInp)

encodedOut=Dense(encodingDim,activation='sigmoid')(inp)

Encoder1=Model(xInp,encodedOut,name='encoder')


decodedOut=Dense(784,activation='sigmoid')(encodedOut)
out=Reshape((28,28))(decodedOut)
optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-6,name='Adam')

Autoencoder1=Model(xInp,out,name='AutoencoderA1')
Autoencoder1.summary()

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

Autoencoder1.compile(optimizer, loss='mse',metrics=['accuracy'])
ae1history=Autoencoder1.fit(x = Input_train_Dataset, y = Input_train_Dataset, batch_size = 32, epochs = 100, verbose = "auto", callbacks=[es], validation_data=(Input_val_Dataset,  Input_val_Dataset))
#, validation_batch_size=1

'''Reconstruction Error-2c'''
print('\nAverage reconstruction Loss :')
trainErr=Autoencoder1.evaluate(x=Input_train_Dataset,y=Input_train_Dataset,batch_size=1, verbose="auto",callbacks=None)
print('Train Data:',trainErr)

#print('\nEvaluation of model on validation data:')
valErr=Autoencoder1.evaluate(x=Input_val_Dataset, y=Input_val_Dataset, batch_size=1, verbose="auto",callbacks=None)
print('Test Data:',valErr)

#print('\nEvaluation of model on test data: Average Reconstruction Error')
testErr=Autoencoder1.evaluate(x=Input_test_Dataset, y=Input_test_Dataset, batch_size=1, verbose="auto",callbacks=None)
print('Test Data:',testErr)

'''visualization-Task2-d'''
trainReconstruct=Autoencoder1.predict(Input_train_Dataset)
plt.plot(ae1history.history['loss'])
n=5
plt.figure(figsize=(20,4))
for i in range(n):
    #displaying original image
    #clss=n
    idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(2,n,i+1)
    plt.imshow(Input_train_Dataset[idx].reshape(28,28),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    #displaying reconstructed image
    ax=plt.subplot(2,n,i+1+n)
    plt.imshow(trainReconstruct[idx].reshape(28,28),cmap='gray')
    #plt.imshow(trainEncode[i].reshape(8,8),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

'''Task3'''
#trainEncode=a1Encoder.predict(Input_train_Dataset)
'''Dataset used for prediction and evaluation in FCNN-Encoded data'''
trainEncode=Encoder1.predict(Input_train_Dataset)
valEncode=Encoder1.predict(Input_val_Dataset)
testEncode=Encoder1.predict(Input_test_Dataset)

'''Fcnn'''
model = keras.Sequential([
        #Flatten(input_shape=(28, 28), name='InputLayer'),
        Dense(512, activation="sigmoid", name="Hlayer1",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(256, activation="sigmoid", name="Hlayer2",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(128, activation="sigmoid", name="Hlayer3",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(5, activation="softmax", name="output"),
        ])
#model.summary()

adam =Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8,name='Adam')


model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

model_fit = model.fit(x = trainEncode, y = Output_train, batch_size = 32, epochs = 10000, verbose = "auto", callbacks=[es], validation_data=(valEncode,  Output_val), validation_batch_size=1)

model.save('/content/drive/MyDrive/DLA4/ae32.h5')
f=open('/content/drive/MyDrive/DLA4/Histae32.pckl','wb')
p.dump(model_fit.history,f)
f.close()

'''FCNN Error'''
print('\nEvaluation of model on train data:')
trainAcc=model.evaluate(x=trainEncode,y=Output_train,batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(trainAcc)

print('\nEvaluation of model on validation data:')
valAcc=model.evaluate(x=valEncode, y=Output_val, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(valAcc)

print('\nEvaluation of model on test data:')
testAcc=model.evaluate(x=testEncode, y=Output_test, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(testAcc)

print('\nPredictions for test data:')
testProb=model.predict(testEncode, batch_size=1, verbose="auto", callbacks=None)
pred=np.argmax(testProb,axis=1)
print(pred)

'''3-3'''
#confusionMatrix=confusion_matrix(Output_test, pred)
confusionMatrix=confusion_matrix(Output_test,pred)
#confusionMatrix=tf.math.confusion_matrix(Output_test, pred5)
print(confusionMatrix)
# Out:
# (11385, 28, 28)
# Model: "AutoencoderA1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img (InputLayer)            [(None, 28, 28)]          0
#
#  InputLayer (Flatten)        (None, 784)               0
#
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 784)               25872
#
#  reshape (Reshape)           (None, 28, 28)            0
#
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 356/356 [==============================] - 2s 3ms/step - loss: 0.0780 - accuracy: 0.0939 - val_loss: 0.0639 - val_accuracy: 0.0981
# Epoch 2/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0634 - accuracy: 0.0994 - val_loss: 0.0634 - val_accuracy: 0.0999
# Epoch 3/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.
100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.2352 - val_loss: 0.0308 - val_accuracy: 0.2322
# Epoch 33/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0306 - accuracy: 0.2361 - val_loss: 0.0306 - val_accuracy: 0.2358
# Epoch 34/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0304 - accuracy: 0.2365 - val_loss: 0.0305 - val_accuracy: 0.2330
# Epoch 35/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0303 - accuracy: 0.2362 - val_loss: 0.0304 - val_accuracy: 0.2362
# Epoch 36/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0302 - accuracy: 0.2374 - val_loss: 0.0303 - val_accuracy: 0.2360
# Epoch 37/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0301 - accuracy: 0.2376 - val_loss: 0.0301 - val_accuracy: 0.2361
# Epoch 38/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0300 - accuracy: 0.2381 - val_loss: 0.0301 - val_accuracy: 0.2353
# Epoch 39/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0299 - accuracy: 0.2388 - val_loss: 0.0300 - val_accuracy: 0.2373
# Epoch 40/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0298 - accuracy: 0.2396 - val_loss: 0.0299 - val_accuracy: 0.2361
# Epoch 41/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0296 - accuracy: 0.2401 - val_loss: 0.0296 - val_accuracy: 0.2389
# Epoch 42/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0292 - accuracy: 0.2414 - val_loss: 0.0292 - val_accuracy: 0.2418
# Epoch 43/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0289 - accuracy: 0.2423 - val_loss: 0.0288 - val_accuracy: 0.2431
# Epoch 44/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0286 - accuracy: 0.2446 - val_loss: 0.0286 - val_accuracy: 0.2422
# Epoch 45/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0283 - accuracy: 0.2455 - val_loss: 0.0284 - val_accuracy: 0.2451
# Epoch 46/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0281 - accuracy: 0.2465 - val_loss: 0.0282 - val_accuracy: 0.2461
# Epoch 47/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0280 - accuracy: 0.2471 - val_loss: 0.0281 - val_accuracy: 0.2452
# Epoch 48/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0278 - accuracy: 0.2479 - val_loss: 0.0279 - val_accuracy: 0.2467
# Epoch 49/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0277 - accuracy: 0.2490 - val_loss: 0.0278 - val_accuracy: 0.2469
# Epoch 50/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0276 - accuracy: 0.2494 - val_loss: 0.0277 - val_accuracy: 0.2475
# Epoch 51/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0275 - accuracy: 0.2498 - val_loss: 0.0276 - val_accuracy: 0.2484
# Epoch 52/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0274 - accuracy: 0.2502 - val_loss: 0.0275 - val_accuracy: 0.2487
# Epoch 53/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0273 - accuracy: 0.2507 - val_loss: 0.0274 - val_accuracy: 0.2506
# Epoch 54/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0272 - accuracy: 0.2517 - val_loss: 0.0273 - val_accuracy: 0.2476
# Epoch 55/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0271 - accuracy: 0.2513 - val_loss: 0.0273 - val_accuracy: 0.2499
# Epoch 56/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0270 - accuracy: 0.2526 - val_loss: 0.0272 - val_accuracy: 0.2498
# Epoch 57/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0270 - accuracy: 0.2529 - val_loss: 0.0271 - val_accuracy: 0.2481
# Epoch 58/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0269 - accuracy: 0.2528 - val_loss: 0.0271 - val_accuracy: 0.2517
# Epoch 59/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0268 - accuracy: 0.2530 - val_loss: 0.0270 - val_accuracy: 0.2505
# Epoch 60/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0268 - accuracy: 0.2538 - val_loss: 0.0269 - val_accuracy: 0.2499
# Epoch 61/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.2533 - val_loss: 0.0269 - val_accuracy: 0.2506
# Epoch 62/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.2544 - val_loss: 0.0268 - val_accuracy: 0.2502
# Epoch 63/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0266 - accuracy: 0.2542 - val_loss: 0.0268 - val_accuracy: 0.2515
# Epoch 64/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0266 - accuracy: 0.2542 - val_loss: 0.0267 - val_accuracy: 0.2517
# Epoch 65/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.2550 - val_loss: 0.0267 - val_accuracy: 0.2527
# Epoch 66/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0265 - accuracy: 0.2549 - val_loss: 0.0267 - val_accuracy: 0.2513
# Epoch 67/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0264 - accuracy: 0.2549 - val_loss: 0.0266 - val_accuracy: 0.2532
# Epoch 68/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0264 - accuracy: 0.2554 - val_loss: 0.0266 - val_accuracy: 0.2515
# Epoch 69/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.2556 - val_loss: 0.0265 - val_accuracy: 0.2539
# Epoch 70/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.2555 - val_loss: 0.0265 - val_accuracy: 0.2509
# Epoch 71/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0263 - accuracy: 0.2559 - val_loss: 0.0264 - val_accuracy: 0.2517
# Epoch 72/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.2557 - val_loss: 0.0264 - val_accuracy: 0.2529
# Epoch 73/100
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.2560 - val_loss: 0.0264 - val_accuracy: 0.2526
# Epoch 74/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.2559 - val_loss: 0.0263 - val_accuracy: 0.2550
# Epoch 75/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.2573 - val_loss: 0.0263 - val_accuracy: 0.2526
# Epoch 76/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.2570 - val_loss: 0.0263 - val_accuracy: 0.2545
# Epoch 77/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.2566 - val_loss: 0.0262 - val_accuracy: 0.2547
# Epoch 78/100
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.2569 - val_loss: 0.0262 - val_accuracy: 0.2533
# Epoch 78: early stopping
#
# Average reconstruction Loss :
# 11385/11385 [==============================] - 12s 1ms/step - loss: 0.0260 - accuracy: 0.2566
# Train Data: [0.025988955050706863, 0.2566315233707428]
# 3795/3795 [==============================] - 4s 1ms/step - loss: 0.0262 - accuracy: 0.2533
# Test Data: [0.02622195892035961, 0.2533314526081085]
# 3795/3795 [==============================] - 5s 1ms/step - loss: 0.0265 - accuracy: 0.2516
# Test Data: [0.026529833674430847, 0.25159984827041626]
# 356/356 [==============================] - 0s 966us/step
# 356/356 [==============================] - 0s 868us/step
# 119/119 [==============================] - 0s 827us/step
# 119/119 [==============================] - 0s 905us/step
# Epoch 1/10000
# 356/356 [==============================] - 7s 18ms/step - loss: 1.2654 - accuracy: 0.4432 - val_loss: 0.5192 - val_accuracy: 0.8619
# Epoch 2/10000
# 356/356 [==============================] - 6s 17ms/step - loss: 0.3602 - accuracy: 0.8726 - val_loss: 0.2655 - val_accuracy: 0.9070
# Epoch 3/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2769 - accuracy: 0.9007 - val_loss: 0.2894 - val_accuracy: 0.8877
# Epoch 4/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2495 - accuracy: 0.9109 - val_loss: 0.2538 - val_accuracy: 0.9057
# Epoch 5/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2545 - accuracy: 0.9058 - val_loss: 0.2340 - val_accuracy: 0.9149
# Epoch 6/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2442 - accuracy: 0.9098 - val_loss: 0.2310 - val_accuracy: 0.9173
# Epoch 7/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2428 - accuracy: 0.9110 - val_loss: 0.2268 - val_accuracy: 0.9141
# Epoch 8/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.2459 - accuracy: 0.9097 - val_loss: 0.2372 - val_accuracy: 0.9107
# Epoch 9/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2382 - accuracy: 0.9120 - val_loss: 0.2462 - val_accuracy: 0.9128
# Epoch 10/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2344 - accuracy: 0.9146 - val_loss: 0.3302 - val_accuracy: 0.8928
# Epoch 11/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2399 - accuracy: 0.9100 - val_loss: 0.2289 - val_accuracy: 0.9202
# Epoch 12/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2367 - accuracy: 0.9127 - val_loss: 0.2470 - val_accuracy: 0.9157
# Epoch 13/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2334 - accuracy: 0.9156 - val_loss: 0.2184 - val_accuracy: 0.9181
# Epoch 14/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2258 - accuracy: 0.9176 - val_loss: 0.2164 - val_accuracy: 0.9202
# Epoch 15/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2269 - accuracy: 0.9153 - val_loss: 0.2327 - val_accuracy: 0.9215
# Epoch 16/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.2274 - accuracy: 0.9146 - val_loss: 0.2317 - val_accuracy: 0.9141
# Epoch 17/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.2251 - accuracy: 0.9150 - val_loss: 0.2387 - val_accuracy: 0.9152
# Epoch 18/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2242 - accuracy: 0.9179 - val_loss: 0.2518 - val_accuracy: 0.9115
# Epoch 19/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2215 - accuracy: 0.9181 - val_loss: 0.2163 - val_accuracy: 0.9212
# Epoch 20/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2209 - accuracy: 0.9183 - val_loss: 0.2510 - val_accuracy: 0.9088
# Epoch 21/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2199 - accuracy: 0.9195 - val_loss: 0.2335 - val_accuracy: 0.9157
# Epoch 22/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2170 - accuracy: 0.9184 - val_loss: 0.2156 - val_accuracy: 0.9228
# Epoch 23/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2153 - accuracy: 0.9210 - val_loss: 0.2453 - val_accuracy: 0.9117
# Epoch 24/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2149 - accuracy: 0.9201 - val_loss: 0.2203 - val_accuracy: 0.9165
# Epoch 25/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2138 - accuracy: 0.9217 - val_loss: 0.2332 - val_accuracy: 0.9120
# Epoch 26/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2135 - accuracy: 0.9211 - val_loss: 0.2005 - val_accuracy: 0.9296
# Epoch 27/10000
# 356/356 [==============================] - 4s 13ms/step - loss: 0.2129 - accuracy: 0.9235 - val_loss: 0.2258 - val_accuracy: 0.9188
# Epoch 28/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.2128 - accuracy: 0.9217 - val_loss: 0.2290 - val_accuracy: 0.9159
# Epoch 29/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2080 - accuracy: 0.9244 - val_loss: 0.2081 - val_accuracy: 0.9233
# Epoch 30/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2064 - accuracy: 0.9245 - val_loss: 0.2029 - val_accuracy: 0.9304
# Epoch 31/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2034 - accuracy: 0.9259 - val_loss: 0.2036 - val_accuracy: 0.9281
# Epoch 32/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.2036 - accuracy: 0.9234 - val_loss: 0.2078 - val_accuracy: 0.9278
# Epoch 33/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.2051 - accuracy: 0.9246 - val_loss: 0.2452 - val_accuracy: 0.9072
# Epoch 34/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.2015 - accuracy: 0.9267 - val_loss: 0.2084 - val_accuracy: 0.9283
# Epoch 35/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.
10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.1534 - accuracy: 0.9443 - val_loss: 0.1702 - val_accuracy: 0.9449
# Epoch 65/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1497 - accuracy: 0.9433 - val_loss: 0.2028 - val_accuracy: 0.9299
# Epoch 66/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1517 - accuracy: 0.9443 - val_loss: 0.1734 - val_accuracy: 0.9386
# Epoch 67/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1486 - accuracy: 0.9466 - val_loss: 0.1737 - val_accuracy: 0.9426
# Epoch 68/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1486 - accuracy: 0.9452 - val_loss: 0.1626 - val_accuracy: 0.9462
# Epoch 69/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.1453 - accuracy: 0.9448 - val_loss: 0.1799 - val_accuracy: 0.9357
# Epoch 70/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.1471 - accuracy: 0.9451 - val_loss: 0.1759 - val_accuracy: 0.9402
# Epoch 71/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1460 - accuracy: 0.9466 - val_loss: 0.1717 - val_accuracy: 0.9341
# Epoch 72/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.1440 - accuracy: 0.9469 - val_loss: 0.1619 - val_accuracy: 0.9426
# Epoch 73/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1425 - accuracy: 0.9471 - val_loss: 0.1690 - val_accuracy: 0.9449
# Epoch 74/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.1410 - accuracy: 0.9490 - val_loss: 0.1665 - val_accuracy: 0.9433
# Epoch 75/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1388 - accuracy: 0.9485 - val_loss: 0.1690 - val_accuracy: 0.9436
# Epoch 76/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1405 - accuracy: 0.9472 - val_loss: 0.1615 - val_accuracy: 0.9449
# Epoch 77/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1372 - accuracy: 0.9491 - val_loss: 0.1630 - val_accuracy: 0.9452
# Epoch 78/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1376 - accuracy: 0.9491 - val_loss: 0.1706 - val_accuracy: 0.9428
# Epoch 79/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1383 - accuracy: 0.9495 - val_loss: 0.1597 - val_accuracy: 0.9452
# Epoch 80/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1351 - accuracy: 0.9492 - val_loss: 0.1649 - val_accuracy: 0.9452
# Epoch 81/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1351 - accuracy: 0.9510 - val_loss: 0.1607 - val_accuracy: 0.9462
# Epoch 82/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1352 - accuracy: 0.9501 - val_loss: 0.1758 - val_accuracy: 0.9410
# Epoch 83/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1327 - accuracy: 0.9517 - val_loss: 0.1659 - val_accuracy: 0.9462
# Epoch 84/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.1319 - accuracy: 0.9527 - val_loss: 0.1706 - val_accuracy: 0.9407
# Epoch 85/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1345 - accuracy: 0.9507 - val_loss: 0.1593 - val_accuracy: 0.9489
# Epoch 86/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1308 - accuracy: 0.9527 - val_loss: 0.1688 - val_accuracy: 0.9428
# Epoch 87/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1306 - accuracy: 0.9502 - val_loss: 0.1563 - val_accuracy: 0.9484
# Epoch 88/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1330 - accuracy: 0.9483 - val_loss: 0.1530 - val_accuracy: 0.9481
# Epoch 89/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1263 - accuracy: 0.9525 - val_loss: 0.1770 - val_accuracy: 0.9383
# Epoch 90/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1246 - accuracy: 0.9544 - val_loss: 0.1613 - val_accuracy: 0.9481
# Epoch 91/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.1243 - accuracy: 0.9543 - val_loss: 0.1491 - val_accuracy: 0.9526
# Epoch 92/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1233 - accuracy: 0.9538 - val_loss: 0.1515 - val_accuracy: 0.9520
# Epoch 93/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.1207 - accuracy: 0.9545 - val_loss: 0.1538 - val_accuracy: 0.9491
# Epoch 94/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1209 - accuracy: 0.9555 - val_loss: 0.1538 - val_accuracy: 0.9489
# Epoch 95/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1213 - accuracy: 0.9533 - val_loss: 0.1555 - val_accuracy: 0.9515
# Epoch 96/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1189 - accuracy: 0.9543 - val_loss: 0.1519 - val_accuracy: 0.9507
# Epoch 97/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1180 - accuracy: 0.9566 - val_loss: 0.1659 - val_accuracy: 0.9449
# Epoch 98/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1153 - accuracy: 0.9571 - val_loss: 0.1569 - val_accuracy: 0.9489
# Epoch 99/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1143 - accuracy: 0.9584 - val_loss: 0.1578 - val_accuracy: 0.9462
# Epoch 100/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1132 - accuracy: 0.9554 - val_loss: 0.1651 - val_accuracy: 0.9412
# Epoch 101/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1124 - accuracy: 0.9580 - val_loss: 0.1514 - val_accuracy: 0.9502
# Epoch 102/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1130 - accuracy: 0.9583 - val_loss: 0.1463 - val_accuracy: 0.9526
# Epoch 103/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1109 - accuracy: 0.9590 - val_loss: 0.1560 - val_accuracy: 0.9481
# Epoch 104/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1096 - accuracy: 0.9578 - val_loss: 0.1691 - val_accuracy: 0.9486
# Epoch 105/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1108 - accuracy: 0.9576 - val_loss: 0.1521 - val_accuracy: 0.9486
# Epoch 106/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1094 - accuracy: 0.9578 - val_loss: 0.1602 - val_accuracy: 0.9465
# Epoch 107/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1065 - accuracy: 0.9596 - val_loss: 0.1460 - val_accuracy: 0.9518
# Epoch 108/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1070 - accuracy: 0.9592 - val_loss: 0.1578 - val_accuracy: 0.9481
# Epoch 109/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.1066 - accuracy: 0.9586 - val_loss: 0.1543 - val_accuracy: 0.9520
# Epoch 110/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1041 - accuracy: 0.9608 - val_loss: 0.1465 - val_accuracy: 0.9542
# Epoch 111/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1041 - accuracy: 0.9590 - val_loss: 0.1612 - val_accuracy: 0.9476
# Epoch 112/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.1017 - accuracy: 0.9610 - val_loss: 0.1450 - val_accuracy: 0.9565
# Epoch 113/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1006 - accuracy: 0.9617 - val_loss: 0.1576 - val_accuracy: 0.9478
# Epoch 114/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.1017 - accuracy: 0.9601 - val_loss: 0.1570 - val_accuracy: 0.9534
# Epoch 115/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0988 - accuracy: 0.9635 - val_loss: 0.1532 - val_accuracy: 0.9547
# Epoch 116/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0997 - accuracy: 0.9615 - val_loss: 0.1493 - val_accuracy: 0.9531
# Epoch 117/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0937 - accuracy: 0.9646 - val_loss: 0.1497 - val_accuracy: 0.9518
# Epoch 118/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0949 - accuracy: 0.9643 - val_loss: 0.1454 - val_accuracy: 0.9518
# Epoch 119/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0950 - accuracy: 0.9654 - val_loss: 0.1399 - val_accuracy: 0.9544
# Epoch 120/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0933 - accuracy: 0.9656 - val_loss: 0.1389 - val_accuracy: 0.9549
# Epoch 121/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0927 - accuracy: 0.9643 - val_loss: 0.1592 - val_accuracy: 0.9507
# Epoch 122/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0909 - accuracy: 0.9662 - val_loss: 0.1516 - val_accuracy: 0.9507
# Epoch 123/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0909 - accuracy: 0.9647 - val_loss: 0.1444 - val_accuracy: 0.9568
# Epoch 124/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0878 - accuracy: 0.9667 - val_loss: 0.1622 - val_accuracy: 0.9499
# Epoch 125/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0862 - accuracy: 0.9674 - val_loss: 0.1392 - val_accuracy: 0.9549
# Epoch 126/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0858 - accuracy: 0.9673 - val_loss: 0.1506 - val_accuracy: 0.9531
# Epoch 127/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0874 - accuracy: 0.9672 - val_loss: 0.1465 - val_accuracy: 0.9547
# Epoch 128/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0859 - accuracy: 0.9673 - val_loss: 0.1469 - val_accuracy: 0.9513
# Epoch 129/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0846 - accuracy: 0.9683 - val_loss: 0.1409 - val_accuracy: 0.9557
# Epoch 130/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.1488 - val_accuracy: 0.9528
# Epoch 131/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0821 - accuracy: 0.9691 - val_loss: 0.1448 - val_accuracy: 0.9570
# Epoch 132/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0801 - accuracy: 0.9693 - val_loss: 0.1489 - val_accuracy: 0.9510
# Epoch 133/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0799 - accuracy: 0.9686 - val_loss: 0.1457 - val_accuracy: 0.9539
# Epoch 134/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0772 - accuracy: 0.9695 - val_loss: 0.1542 - val_accuracy: 0.9526
# Epoch 135/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0758 - accuracy: 0.9686 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 136/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0773 - accuracy: 0.9700 - val_loss: 0.1461 - val_accuracy: 0.9544
# Epoch 137/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0746 - accuracy: 0.9715 - val_loss: 0.1520 - val_accuracy: 0.9552
# Epoch 138/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0792 - accuracy: 0.9688 - val_loss: 0.1413 - val_accuracy: 0.9581
# Epoch 139/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0741 - accuracy: 0.9727 - val_loss: 0.1531 - val_accuracy: 0.9536
# Epoch 140/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0724 - accuracy: 0.9724 - val_loss: 0.1476 - val_accuracy: 0.9531
# Epoch 141/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0722 - accuracy: 0.9719 - val_loss: 0.1440 - val_accuracy: 0.9549
# Epoch 142/10000
# 356/356 [==============================] - 7s 18ms/step - loss: 0.0696 - accuracy: 0.9739 - val_loss: 0.1499 - val_accuracy: 0.9560
# Epoch 143/10000
# 356/356 [==============================] - 6s 18ms/step - loss: 0.0705 - accuracy: 0.9723 - val_loss: 0.1438 - val_accuracy: 0.9523
# Epoch 144/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0712 - accuracy: 0.9735 - val_loss: 0.1426 - val_accuracy: 0.9563
# Epoch 145/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.0698 - accuracy: 0.9729 - val_loss: 0.1447 - val_accuracy: 0.9555
# Epoch 145: early stopping
#
# Evaluation of model on train data:
# 11385/11385 [==============================] - 13s 1ms/step - loss: 0.0571 - accuracy: 0.9780
# ['loss', 'accuracy']
# [0.05709756538271904, 0.9780412912368774]
#
# Evaluation of model on validation data:
# 3795/3795 [==============================] - 4s 1ms/step - loss: 0.1447 - accuracy: 0.9555
# ['loss', 'accuracy']
# [0.1447121649980545, 0.955467700958252]
#
# Evaluation of model on test data:
# 3795/3795 [==============================] - 5s 1ms/step - loss: 0.1302 - accuracy: 0.9563
# ['loss', 'accuracy']
# [0.13019528985023499, 0.956258237361908]
#
# Predictions for test data:
# 3795/3795 [==============================] - 4s 941us/step
# [0 0 0 ... 3 3 3]
# [[732   1  12   1  13]
#  [  1 748   4   4   2]
#  [  6   3 745   1   4]
#  [  0   5   3 703  48]
#  [  9   4   2  43 701]]
