# %% [markdown]
# #512,256,128

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os,sys
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Input,Flatten,Reshape
from tensorflow.keras.models import Model
from keras import initializers
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import pickle as p
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix 

initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=100)
#print('Initializer: ',initializer)

def Upload_Dataset(Dataset_Path):
    
    Path_train_Dataset = Dataset_Path+"/train"
    Path_test_Dataset = Dataset_Path+"/test"
    Path_val_Dataset = Dataset_Path+"/val"
    
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = [], [], []
    Output_train, Output_test, Output_val = [], [], []

    for j in os.listdir(Path_train_Dataset):

        if j != ".DS_Store":
            for k in os.listdir(Path_train_Dataset+"/"+j):
                Input_train_Dataset.append(cv2.imread(Path_train_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j == '6'):
                    Output_train.append(int(2))
                elif(j == '7'):
                    Output_train.append(int(3))
                elif(j == '9'):
                    Output_train.append(int(4))
                else:
                    Output_train.append(int(j))

            for k in os.listdir(Path_test_Dataset+"/"+j):
                Input_test_Dataset.append(cv2.imread(Path_test_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_test.append(int(2))
                elif(j=='7'):
                    Output_test.append(int(3))
                elif(j=='9'):
                    Output_test.append(int(4))
                else:
                    Output_test.append(int(j))

            for k in os.listdir(Path_val_Dataset+"/"+j):
                Input_val_Dataset.append(cv2.imread(Path_val_Dataset+"/"+j+"/"+k, cv2.IMREAD_GRAYSCALE))
                if(j=='6'):
                    Output_val.append(int(2))
                elif(j=='7'):
                    Output_val.append(int(3))
                elif(j=='9'):
                    Output_val.append(int(4))
                else:
                    Output_val.append(int(j))
        
    #print(Output_train)            
    Input_train_Dataset, Input_test_Dataset, Input_val_Dataset = np.array(Input_train_Dataset), np.array(Input_test_Dataset), np.array(Input_val_Dataset)
    #Output_train, Output_test, Output_val = np.array(list(map(int, Output_train))), np.array(list(map(int, Output_test))), np.array(list(map(int, Output_val)))
    Output_train, Output_test, Output_val = np.array(Output_train), np.array(Output_test), np.array(Output_val)
    #print(Output_train) 
    return Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val



#providing path of  MNIST dataset
Dataset_Path = "/content/drive/MyDrive/Group_1"


#calling Upload_Dataset function
Input_train_Dataset, Input_test_Dataset,Input_val_Dataset, Output_train, Output_test, Output_val= Upload_Dataset(Dataset_Path)
#print(Input_train_Dataset.shape,'\n')

#
Input_train_Dataset=Input_train_Dataset/255
Input_test_Dataset=Input_test_Dataset/255
Input_val_Dataset=Input_val_Dataset/255
'''bottleneck dimension'''
encodingDim=128
print(Input_train_Dataset.shape)

xInp=Input(shape=(28,28),name="img")
inp=Flatten(input_shape=(28, 28), name='InputLayer')(xInp)

encodedOut=Dense(encodingDim,activation='sigmoid')(inp)

Encoder1=Model(xInp,encodedOut,name='encoder')


decodedOut=Dense(784,activation='sigmoid')(encodedOut)
out=Reshape((28,28))(decodedOut)
optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-6,name='Adam')

Autoencoder1=Model(xInp,out,name='AutoencoderA1')
Autoencoder1.summary()

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

Autoencoder1.compile(optimizer, loss='mse',metrics=['accuracy'])
ae1history=Autoencoder1.fit(x = Input_train_Dataset, y = Input_train_Dataset, batch_size = 32, epochs = 100, verbose = "auto", callbacks=[es], validation_data=(Input_val_Dataset,  Input_val_Dataset))
#, validation_batch_size=1

'''Reconstruction Error-2c'''
print('\nAverage reconstruction Loss :')
trainErr=Autoencoder1.evaluate(x=Input_train_Dataset,y=Input_train_Dataset,batch_size=1, verbose="auto",callbacks=None)
print('Train Data:',trainErr)

#print('\nEvaluation of model on validation data:')
valErr=Autoencoder1.evaluate(x=Input_val_Dataset, y=Input_val_Dataset, batch_size=1, verbose="auto",callbacks=None)
print('Test Data:',valErr)

#print('\nEvaluation of model on test data: Average Reconstruction Error')
testErr=Autoencoder1.evaluate(x=Input_test_Dataset, y=Input_test_Dataset, batch_size=1, verbose="auto",callbacks=None)
print('Test Data:',testErr)

'''visualization-Task2-d'''
trainReconstruct=Autoencoder1.predict(Input_train_Dataset)
plt.plot(ae1history.history['loss'])
n=5
plt.figure(figsize=(20,4))
for i in range(n):
    #displaying original image
    #clss=n
    idx=np.where(Output_train==i)[0][0]
    ax=plt.subplot(2,n,i+1)
    plt.imshow(Input_train_Dataset[idx].reshape(28,28),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    #displaying reconstructed image
    ax=plt.subplot(2,n,i+1+n)
    plt.imshow(trainReconstruct[idx].reshape(28,28),cmap='gray')
    #plt.imshow(trainEncode[i].reshape(8,8),cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

'''Task3'''
#trainEncode=a1Encoder.predict(Input_train_Dataset)
'''Dataset used for prediction and evaluation in FCNN-Encoded data'''
trainEncode=Encoder1.predict(Input_train_Dataset)
valEncode=Encoder1.predict(Input_val_Dataset)
testEncode=Encoder1.predict(Input_test_Dataset)

'''Fcnn'''
model = keras.Sequential([
        #Flatten(input_shape=(28, 28), name='InputLayer'),
        Dense(512, activation="sigmoid", name="Hlayer1",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(256, activation="sigmoid", name="Hlayer2",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(128, activation="sigmoid", name="Hlayer3",kernel_initializer=initializer, bias_initializer=initializers.Zeros()),
        Dense(5, activation="softmax", name="output"),
        ])
#model.summary()

adam =Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-8,name='Adam')


model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='loss',min_delta=0.0001, patience=3,verbose=1)

model_fit = model.fit(x = trainEncode, y = Output_train, batch_size = 32, epochs = 10000, verbose = "auto", callbacks=[es], validation_data=(valEncode,  Output_val), validation_batch_size=1)

model.save('/content/drive/MyDrive/DLA4/ae32.h5')
f=open('/content/drive/MyDrive/DLA4/Histae128.pckl','wb')
p.dump(model_fit.history,f)
f.close()

'''FCNN Error'''
print('\nEvaluation of model on train data:')
trainAcc=model.evaluate(x=trainEncode,y=Output_train,batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(trainAcc)

print('\nEvaluation of model on validation data:')
valAcc=model.evaluate(x=valEncode, y=Output_val, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(valAcc)

print('\nEvaluation of model on test data:')
testAcc=model.evaluate(x=testEncode, y=Output_test, batch_size=1, verbose="auto",callbacks=None)
print(model.metrics_names)
print(testAcc)

print('\nPredictions for test data:')
testProb=model.predict(testEncode, batch_size=1, verbose="auto", callbacks=None)
pred=np.argmax(testProb,axis=1)
print(pred)

'''3-3'''
#confusionMatrix=confusion_matrix(Output_test, pred)
confusionMatrix=confusion_matrix(Output_test,pred)
#confusionMatrix=tf.math.confusion_matrix(Output_test, pred5)
print(confusionMatrix)
# Out:
# (11385, 28, 28)
# Model: "AutoencoderA1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img (InputLayer)            [(None, 28, 28)]          0
#
#  InputLayer (Flatten)        (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 784)               101136
#
#  reshape (Reshape)           (None, 28, 28)            0
#
# =================================================================
# Total params: 201,616
# Trainable params: 201,616
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0594 - accuracy: 0.1356 - val_loss: 0.0413 - val_accuracy: 0.1866
# Epoch 2/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0343 - accuracy: 0.2273 - val_loss: 0.0293 - val_accuracy: 0.2518
# Epoch 3/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0259 - accuracy: 0.2676 - val_loss: 0.0231 - val_accuracy: 0.2785
# Epoch 4/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0208 - accuracy: 0.2916 - val_loss: 0.0189 - val_accuracy: 0.2974
# Epoch 5/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0171 - accuracy: 0.3065 - val_loss: 0.0158 - val_accuracy: 0.3105
# Epoch 6/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0144 - accuracy: 0.3173 - val_loss: 0.0135 - val_accuracy: 0.3185
# Epoch 7/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0124 - accuracy: 0.3250 - val_loss: 0.0117 - val_accuracy: 0.3249
# Epoch 8/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0108 - accuracy: 0.3312 - val_loss: 0.0103 - val_accuracy: 0.3300
# Epoch 9/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0096 - accuracy: 0.3357 - val_loss: 0.0093 - val_accuracy: 0.3348
# Epoch 10/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0087 - accuracy: 0.3403 - val_loss: 0.0085 - val_accuracy: 0.3367
# Epoch 11/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0079 - accuracy: 0.3427 - val_loss: 0.0078 - val_accuracy: 0.3409
# Epoch 12/100
# 356/356 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.3460 - val_loss: 0.0072 - val_accuracy: 0.3418
# Epoch 13/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0067 - accuracy: 0.3477 - val_loss: 0.0068 - val_accuracy: 0.3450
# Epoch 14/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0063 - accuracy: 0.3502 - val_loss: 0.0063 - val_accuracy: 0.3470
# Epoch 15/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0059 - accuracy: 0.3522 - val_loss: 0.0060 - val_accuracy: 0.3502
# Epoch 16/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0056 - accuracy: 0.3540 - val_loss: 0.0057 - val_accuracy: 0.3502
# Epoch 17/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.3553 - val_loss: 0.0054 - val_accuracy: 0.3525
# Epoch 18/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0050 - accuracy: 0.3567 - val_loss: 0.0052 - val_accuracy: 0.3538
# Epoch 19/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0048 - accuracy: 0.3581 - val_loss: 0.0050 - val_accuracy: 0.3557
# Epoch 20/100
# 356/356 [==============================] - 2s 7ms/step - loss: 0.0046 - accuracy: 0.3591 - val_loss: 0.0048 - val_accuracy: 0.3564
# Epoch 21/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0044 - accuracy: 0.3601 - val_loss: 0.0046 - val_accuracy: 0.3571
# Epoch 22/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0042 - accuracy: 0.3609 - val_loss: 0.0045 - val_accuracy: 0.3588
# Epoch 23/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0040 - accuracy: 0.3624 - val_loss: 0.0043 - val_accuracy: 0.3584
# Epoch 24/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.3626 - val_loss: 0.0042 - val_accuracy: 0.3605
# Epoch 25/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.3638 - val_loss: 0.0041 - val_accuracy: 0.3613
# Epoch 26/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0036 - accuracy: 0.3643 - val_loss: 0.0040 - val_accuracy: 0.3615
# Epoch 27/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0035 - accuracy: 0.3653 - val_loss: 0.0038 - val_accuracy: 0.3619
# Epoch 28/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0034 - accuracy: 0.3661 - val_loss: 0.0038 - val_accuracy: 0.3630
# Epoch 29/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0033 - accuracy: 0.3667 - val_loss: 0.0037 - val_accuracy: 0.3637
# Epoch 30/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0032 - accuracy: 0.3672 - val_loss: 0.0036 - val_accuracy: 0.3641
# Epoch 31/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0032 - accuracy: 0.3680 - val_loss: 0.0035 - val_accuracy: 0.3647
# Epoch 32/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0031 - accuracy: 0.3686 - val_loss: 0.0034 - val_accuracy: 0.3679
# Epoch 33/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.3688 - val_loss: 0.0034 - val_accuracy: 0.3659
# Epoch 34/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0029 - accuracy: 0.3688 - val_loss: 0.0033 - val_accuracy: 0.3656
# Epoch 35/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0029 - accuracy: 0.3697 - val_loss: 0.0032 - val_accuracy: 0.3668
# Epoch 36/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0028 - accuracy: 0.3697 - val_loss: 0.0032 - val_accuracy: 0.3679
# Epoch 37/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0028 - accuracy: 0.3709 - val_loss: 0.0031 - val_accuracy: 0.3691
# Epoch 38/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0027 - accuracy: 0.3711 - val_loss: 0.0031 - val_accuracy: 0.3669
# Epoch 39/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0026 - accuracy: 0.3714 - val_loss: 0.0030 - val_accuracy: 0.3683
# Epoch 40/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0026 - accuracy: 0.3719 - val_loss: 0.0030 - val_accuracy: 0.3692
# Epoch 41/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0025 - accuracy: 0.3725 - val_loss: 0.0029 - val_accuracy: 0.3695
# Epoch 42/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0025 - accuracy: 0.3726 - val_loss: 0.0029 - val_accuracy: 0.3702
# Epoch 43/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0025 - accuracy: 0.3733 - val_loss: 0.0029 - val_accuracy: 0.3709
# Epoch 44/100
# 356/356 [==============================] - 2s 6ms/step - loss: 0.0024 - accuracy: 0.3735 - val_loss: 0.0028 - val_accuracy: 0.3706
# Epoch 45/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0024 - accuracy: 0.3734 - val_loss: 0.0028 - val_accuracy: 0.3697
# Epoch 46/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 0.3739 - val_loss: 0.0027 - val_accuracy: 0.3693
# Epoch 47/100
# 356/356 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 0.3742 - val_loss: 0.0027 - val_accuracy: 0.3709
# Epoch 48/100
# 356/356 [==============================] - 2s 4ms/step - loss: 0.0023 - accuracy: 0.3741 - val_loss: 0.0027 - val_accuracy: 0.3700
# Epoch 49/100
# 356/356 [==============================] - 1s 4ms/step - loss: 0.0022 - accuracy: 0.3745 - val_loss: 0.0026 - val_accuracy: 0.3704
# Epoch 49: early stopping
#
# Average reconstruction Loss :
# 11385/11385 [==============================] - 13s 1ms/step - loss: 0.0022 - accuracy: 0.3748
# Train Data: [0.002198591595515609, 0.37475061416625977]
# 3795/3795 [==============================] - 4s 1ms/step - loss: 0.0026 - accuracy: 0.3704
# Test Data: [0.0026421532966196537, 0.37043100595474243]
# 3795/3795 [==============================] - 5s 1ms/step - loss: 0.0027 - accuracy: 0.3739
# Test Data: [0.002722757402807474, 0.3738565742969513]
# 356/356 [==============================] - 1s 2ms/step
# 356/356 [==============================] - 0s 971us/step
# 119/119 [==============================] - 0s 1ms/step
# 119/119 [==============================] - 0s 981us/step
# Epoch 1/10000
# 356/356 [==============================] - 8s 19ms/step - loss: 0.6792 - accuracy: 0.7332 - val_loss: 0.1500 - val_accuracy: 0.9542
# Epoch 2/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.1297 - accuracy: 0.9593 - val_loss: 0.1309 - val_accuracy: 0.9563
# Epoch 3/10000
# 356/356 [==============================] - 4s 12ms/step - loss: 0.1096 - accuracy: 0.9649 - val_loss: 0.0922 - val_accuracy: 0.9679
# Epoch 4/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.1016 - accuracy: 0.9677 - val_loss: 0.0965 - val_accuracy: 0.9676
# Epoch 5/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0941 - accuracy: 0.9695 - val_loss: 0.1016 - val_accuracy: 0.9673
# Epoch 6/10000
# 356/356 [==============================] - 8s 22ms/step - loss: 0.0944 - accuracy: 0.9695 - val_loss: 0.0857 - val_accuracy: 0.9718
# Epoch 7/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0874 - accuracy: 0.9714 - val_loss: 0.0992 - val_accuracy: 0.9671
# Epoch 8/10000
# 356/356 [==============================] - 6s 17ms/step - loss: 0.0818 - accuracy: 0.9747 - val_loss: 0.0981 - val_accuracy: 0.9686
# Epoch 9/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0815 - accuracy: 0.9726 - val_loss: 0.0847 - val_accuracy: 0.9692
# Epoch 10/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.0786 - accuracy: 0.9742 - val_loss: 0.0793 - val_accuracy: 0.9713
# Epoch 11/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0790 - accuracy: 0.9733 - val_loss: 0.1007 - val_accuracy: 0.9671
# Epoch 12/10000
# 356/356 [==============================] - 5s 15ms/step - loss: 0.0719 - accuracy: 0.9765 - val_loss: 0.0778 - val_accuracy: 0.9742
# Epoch 13/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0681 - accuracy: 0.9769 - val_loss: 0.0775 - val_accuracy: 0.9723
# Epoch 14/10000
# 356/356 [==============================] - 5s 15ms/step - loss: 0.0687 - accuracy: 0.9772 - val_loss: 0.0822 - val_accuracy: 0.9729
# Epoch 15/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0644 - accuracy: 0.9789 - val_loss: 0.1119 - val_accuracy: 0.9623
# Epoch 16/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0637 - accuracy: 0.9784 - val_loss: 0.0771 - val_accuracy: 0.9723
# Epoch 17/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.0613 - accuracy: 0.9801 - val_loss: 0.0802 - val_accuracy: 0.9708
# Epoch 18/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0581 - accuracy: 0.9822 - val_loss: 0.0802 - val_accuracy: 0.9729
# Epoch 19/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0547 - accuracy: 0.9819 - val_loss: 0.0694 - val_accuracy: 0.9760
# Epoch 20/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0516 - accuracy: 0.9827 - val_loss: 0.0694 - val_accuracy: 0.9776
# Epoch 21/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0494 - accuracy: 0.9851 - val_loss: 0.0670 - val_accuracy: 0.9776
# Epoch 22/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0479 - accuracy: 0.9845 - val_loss: 0.0669 - val_accuracy: 0.9779
# Epoch 23/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0445 - accuracy: 0.9846 - val_loss: 0.0744 - val_accuracy: 0.9779
# Epoch 24/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.0869 - val_accuracy: 0.9731
# Epoch 25/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0425 - accuracy: 0.9854 - val_loss: 0.0654 - val_accuracy: 0.9792
# Epoch 26/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.0619 - val_accuracy: 0.9789
# Epoch 27/10000
# 356/356 [==============================] - 6s 16ms/step - loss: 0.0377 - accuracy: 0.9870 - val_loss: 0.0658 - val_accuracy: 0.9784
# Epoch 28/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.0704 - val_accuracy: 0.9784
# Epoch 29/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0337 - accuracy: 0.9890 - val_loss: 0.0710 - val_accuracy: 0.9802
# Epoch 30/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.0725 - val_accuracy: 0.9789
# Epoch 31/10000
# 356/356 [==============================] - 6s 16ms/step - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.0670 - val_accuracy: 0.9802
# Epoch 32/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0298 - accuracy: 0.9887 - val_loss: 0.0660 - val_accuracy: 0.9823
# Epoch 33/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.0750 - val_accuracy: 0.9797
# Epoch 34/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0276 - accuracy: 0.9909 - val_loss: 0.0737 - val_accuracy: 0.9784
# Epoch 35/10000
# 356/356 [==============================] - 5s 15ms/step - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.0810 - val_accuracy: 0.9760
# Epoch 36/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0680 - val_accuracy: 0.9818
# Epoch 37/10000
# 356/356 [==============================] - 5s 15ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.0638 - val_accuracy: 0.9810
# Epoch 38/10000
# 356/356 [==============================] - 7s 20ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.0688 - val_accuracy: 0.9805
# Epoch 39/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.0753 - val_accuracy: 0.9818
# Epoch 40/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.1082 - val_accuracy: 0.9758
# Epoch 41/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0887 - val_accuracy: 0.9787
# Epoch 42/10000
# 356/356 [==============================] - 6s 16ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0701 - val_accuracy: 0.9808
# Epoch 43/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.1068 - val_accuracy: 0.9771
# Epoch 44/10000
# 356/356 [==============================] - 6s 16ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0820 - val_accuracy: 0.9808
# Epoch 45/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0678 - val_accuracy: 0.9837
# Epoch 46/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.0656 - val_accuracy: 0.9842
# Epoch 47/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0723 - val_accuracy: 0.9831
# Epoch 48/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.1093 - val_accuracy: 0.9681
# Epoch 49/10000
# 356/356 [==============================] - 5s 14ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0718 - val_accuracy: 0.9839
# Epoch 50/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.0771 - val_accuracy: 0.9821
# Epoch 51/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0718 - val_accuracy: 0.9845
# Epoch 52/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.0776 - val_accuracy: 0.9834
# Epoch 53/10000
# 356/356 [==============================] - 5s 13ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0922 - val_accuracy: 0.9805
# Epoch 54/10000
# 356/356 [==============================] - 7s 19ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0738 - val_accuracy: 0.9829
# Epoch 54: early stopping
#
# Evaluation of model on train data:
# 11385/11385 [==============================] - 13s 1ms/step - loss: 0.0070 - accuracy: 0.9979
# ['loss', 'accuracy']
# [0.006987466011196375, 0.9978919625282288]
#
# Evaluation of model on validation data:
# 3795/3795 [==============================] - 4s 1ms/step - loss: 0.0738 - accuracy: 0.9829
# ['loss', 'accuracy']
# [0.07381836324930191, 0.9828721880912781]
#
# Evaluation of model on test data:
# 3795/3795 [==============================] - 5s 1ms/step - loss: 0.0859 - accuracy: 0.9805
# ['loss', 'accuracy']
# [0.0858701840043068, 0.9805006384849548]
#
# Predictions for test data:
# 3795/3795 [==============================] - 4s 948us/step
# [0 0 0 ... 3 3 3]
# [[751   1   4   3   0]
#  [  2 751   2   3   1]
#  [  5   2 750   1   1]
#  [  2   7   1 742   7]
#  [  7   7   0  18 727]]
